# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../src/backend")))
from backend.aws.ec2 import list_ec2_instances
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       1 import sys
#       2 import os
#       3 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../../src/backend")))
# ----> 4 from backend.aws.ec2 import list_ec2_instances
#
# File c:\Users\prana\Projects\cost-eco-vision\src\backend\aws\ec2.py:1
# ----> 1 from connections.aws import get_client, get_region
#       2 from connections.db import get_resource_from_db, save_resource_in_db
#       3 from aws.util import  get_resource_cost, should_run_agent
#
# ModuleNotFoundError: No module named 'connections'

# %%
def generate_ec2_recommendations(resource):
    # use metrics + config
    return []
